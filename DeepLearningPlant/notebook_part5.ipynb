# %%
# %run train.py --part 2 --use-iou-loss --epochs 5 --lambda-iou 1 --batch-size 8
# Out:
# Device: cuda
# Dataset : 898 images | Train : 718 | Val : 180
# Expérience : part2_same_res_iou
# Paramètres entraînables : 7,869,956
#
# ...
# Début de l'entraînement — 5 époques
# ...
#     [CE: 0.6931, IoU: 0.7870]
# Epoch   1/5 (386.9s) | Train Loss: 1.4800  Acc: 0.6017  F1: 0.6603 | Val Loss: 0.5704  Acc: 0.7667  F1: 0.8073
#   → Meilleur modèle sauvé (F1: 0.8073)
#     [CE: 0.6698, IoU: 0.7766]
# Epoch   2/5 (405.5s) | Train Loss: 1.4464  Acc: 0.6156  F1: 0.6714 | Val Loss: 0.5485  Acc: 0.7889  F1: 0.8241
#   → Meilleur modèle sauvé (F1: 0.8241)
#     [CE: 0.6292, IoU: 0.7696]
# Epoch   3/5 (406.7s) | Train Loss: 1.3987  Acc: 0.6574  F1: 0.6830 | Val Loss: 0.5880  Acc: 0.6167  F1: 0.7273
#     [CE: 0.5984, IoU: 0.7652]
# Epoch   4/5 (403.7s) | Train Loss: 1.3636  Acc: 0.6783  F1: 0.7240 | Val Loss: 0.6264  Acc: 0.6111  F1: 0.7266
#     [CE: 0.5961, IoU: 0.7608]
# Epoch   5/5 (400.6s) | Train Loss: 1.3569  Acc: 0.6741  F1: 0.7167 | Val Loss: 0.5107  Acc: 0.7611  F1: 0.8089
#
# ...
